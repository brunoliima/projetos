# %% [markdown]
# <a href="https://colab.research.google.com/github/brunoliima/projetos/blob/main/Imersao1_Bruno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IMERSÃO DADOS - BRUNO LIMA

# %% [markdown]
# - #imersaodados #alura

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados, compression='zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize=True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()
plt.title('Formas de Tratamento')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
dados['tempo'].value_counts().plot.pie()
plt.title('Tempo do Tratamento')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()

# %% [markdown]
# ### Desafio 01: Investigar por que a classe tratamento é tão desbalanceada ?
#
# ### Desafio 02: Plotar as 5 últimas linhas da tabela
#
# ### Desafio 03: Proporção das classes tratamento.
#
# ### Desafio 04: Quantos tipos de drogas foram investigados ?
#
# ### Desafio 05: Procurar na documentação o método query(pandas).
#
# ### Desafio 06: Renomear as colunas tirando o hífen.
#
# ### Desafio 07: Colocar Título (Matplotlib.pyplot)
#
# ### Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# ### Desafio 01:

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
plt.bar(dados['tratamento'].unique(), dados['tratamento'].value_counts())
plt.title('Tratamentos')
plt.ylabel('Observações')
plt.xlabel('Tipo de Tratamento')
plt.show()

# %% [markdown]
# ### Foram aplicadas mais doses no grupo "com_droga"

# %% [markdown]
# ### Desafio 02:

# %%
dados[-5:]
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ### Desafio 03:

# %%
droga = dados[dados['tratamento'] == 'com_droga']
controle = dados[dados['tratamento'] == 'com_controle']
total = dados['tratamento']

droga = len(droga)
controle = len(controle)
total = len(total)

perc_droga = droga/total
perc_controle = controle/total

print(f'O percentual do com_droga na classe Tratamento é de {perc_droga:.2%}.\nJá o percentual do com_controle é de {perc_controle:.2%}')
# Out:
# O percentual do com_droga na classe Tratamento é de 92.16%.
# Já o percentual do com_controle é de 7.84%

# %% [markdown]
# ### Desafio 04:

# %% [markdown]
# Quantos tipos de drogas foram analisados

# %%
qtd_drogas = dados['droga'].value_counts()
print(f'{qtd_drogas.shape[0]} Tipos de drogas foram analisados')
# Out:
# 3289 Tipos de drogas foram analisados

# %% [markdown]
# ### Desafio 05:

# %% [markdown]
# pandas.DataFrame.query
# DataFrame.query(expr, inplace=False, **kwargs)[source]
# Query the columns of a DataFrame with a boolean expression.
#
# Parameters
# exprstr
# The query string to evaluate.
#
# You can refer to variables in the environment by prefixing them with an ‘@’ character like @a + b.
#
# You can refer to column names that are not valid Python variable names by surrounding them in backticks. Thus, column names containing spaces or punctuations (besides underscores) or starting with digits must be surrounded by backticks. (For example, a column named “Area (cm^2) would be referenced as Area (cm^2)). Column names which are Python keywords (like “list”, “for”, “import”, etc) cannot be used.
#
# For example, if one of your columns is called a a and you want to sum it with b, your query should be `a a` + b.
#
# New in version 0.25.0: Backtick quoting introduced.
#
# New in version 1.0.0: Expanding functionality of backtick quoting for more than only spaces.
#
# inplacebool
# Whether the query should modify the data in place or return a modified copy.
#
# **kwargs
# See the documentation for eval() for complete details on the keyword arguments accepted by DataFrame.query().
#
# Returns
# DataFrame or None
# DataFrame resulting from the provided query expression or None if inplace=True.

# %% [markdown]
# ### Desafio 06:

# %%
dados.columns = dados.columns.str.replace('-', '')

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# ### Desafio 07:

# %%
dados['tempo'].value_counts().plot.bar(title= 'Experimentos por Tempo de Duração', xlabel= 'Tempo (horas)', ylabel='Número de Experimentos', rot='horizontal')

# %% [markdown]
# ### Desafio 08:

# %% [markdown]
# Com essa aula, foi possível observar que o número de observações feitas com drogas foi bem superior, assim como a maior parte dos experimentos foram feitos em um período de 48 horas.
#
# Do total de 23813 itens existentes na base, 92,16% dos tratamentos foram feitos com droga e apenas 7,84% foram feitos com controle.
